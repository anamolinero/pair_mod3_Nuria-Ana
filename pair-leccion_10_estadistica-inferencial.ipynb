# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
#import scipy.stats as stats
import scipy.stats as stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# lo primero que hacemos es cargar el dataframe que vamos a usar para esta lección
df = pd.read_csv("archivos/world_data_full_apply_nulos.csv",index_col=0) 
df.head(2)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# ...

# %% [markdown]
# Ejercicios intervalo de confianza. Al igual que en el caso del ejercicio de la clase, piensa un motivo por el que sería interesante calcular estos intervalos de confianza para la extracción de insights.
#
# Intervalo de Confianza para la Esperanza de Vida Contexto: Trabajas en una organización de salud global y deseas estimar el intervalo de confianza al 95% para la esperanza de vida promedio de cada continente. Nota: Cuidado porque puede que os salgan algunos nulos, genera un código para que no salgan nulos en los intervalos de confianza.

# %%
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %%
#intervalo de confianza 95%

    
for c in df["continent"].unique():
    df_p = df[df["continent"] == c]
    media = df_p["life_expectancy"].mean()
    error = stats.sem(df_p["life_expectancy"],nan_policy="omit")
    grados_libertad = len(df_p["life_expectancy"])-1
    nivel_confianza = 0.95
    valor_critico = stats.t.ppf((1 + nivel_confianza) / 2, df=grados_libertad)
    salto = valor_critico * error
    limite_sup = media + salto
    limite_inf = media - salto
    print(c)
    print(f"{round (limite_inf,2)}, , {round(limite_sup,2)}")
    print("---------------------------------------------------------")
# Out:
# Asia
# 72.33, , 75.24
# ---------------------------------------------------------
# Europe
# 78.09, , 80.31
# ---------------------------------------------------------
# Africa
# 62.06, , 65.39
# ---------------------------------------------------------
# Central America
# 73.04, , 76.34
# ---------------------------------------------------------
# South America
# 72.99, , 76.64
# ---------------------------------------------------------
# Oceania
# 67.47, , 74.78
# ---------------------------------------------------------
# North America
# 58.6, , 101.8
# ---------------------------------------------------------
# nan
# nan, , nan
# ---------------------------------------------------------

# %% [markdown]
# Intervalo de Confianza para el PIB Contexto: Eres una economista y quieres calcular el intervalo de confianza al 90% para el Producto Interno Bruto (PIB) de los continentes.

# %%
def calcular_confianza (dato1,dato2) : 
    for c in df[dato2].unique():
        df_p = df[df[dato2] == c]
        media = df_p[dato1].mean()
        error = stats.sem(df_p[dato1],nan_policy="omit")
        grados_libertad = len(df_p[dato1])-1
        nivel_confianza = 0.99
        valor_critico = stats.t.ppf((1 + nivel_confianza) / 2, df=grados_libertad)
        salto = valor_critico * error
        limite_sup = media + salto
        limite_inf = media - salto
        print(c)
        print(f"{round (limite_inf,2)}, , {round(limite_sup,2)}")
        print("---------------------------------------------------------")

# %%
calcular_confianza("gdp","continent")
# Out:
# Asia
# -409780025452.07, , 2084170556753.79
# ---------------------------------------------------------
# Europe
# 153067498378.94, , 820428882229.54
# ---------------------------------------------------------
# Africa
# 13855223077.9, , 78305895209.83
# ---------------------------------------------------------
# Central America
# -88906258670.27, , 265866114076.47
# ---------------------------------------------------------
# South America
# -119196769004.23, , 716064140101.77
# ---------------------------------------------------------
# Oceania
# -182119839806.54, , 415696951311.11
# ---------------------------------------------------------
# North America
# -615159115069629.9, , 638323240699149.9
# ---------------------------------------------------------
# nan
# nan, , nan
# ---------------------------------------------------------
